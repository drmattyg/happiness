# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
h = 128
w = 128
def happiness(b):
    x = np.arange(0, w - 1, 1)
    def f(x):
        return (b*h/2)*np.sin(x*np.pi/w)
    plt.plot(x, f(x), '-')

# %%
plt.subplot(3, 3, 1)
happiness(-1)
plt.subplot(3, 3, 2)
happiness(0)
plt.subplot(3, 3, 3)
happiness(1)

# %%
happiness(0)

# %%
happiness(1)

# %%
def happy_circle(v):
    v = v - np.sign(v)*0.0001
    r = (w/2)/np.abs(v)
    x = np.arange(0, w, 1)
    d = 0.5*np.sqrt(4*r**2 - (w**2))
    y0 = h/2 + np.sign(v)*d
    x0 = w/2
    y = -np.sign(v)*np.sqrt(r**2 - ((x - x0) **2)) + y0
    plt.xlim(0, w-1)
    plt.ylim(-10, h + 10)
    plt.plot(x, y)

# %%
for v in np.arange(-1.0, 1.2, 0.2):
    happy_circle(v)

# %%
happy_circle(1)

# %%
happy_circle(-1)

# %%
happy_circle(0)
# Out:
# /Users/mgordon/.virtualenv/production/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/mgordon/.virtualenv/production/lib/python3.5/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in double_scalars
#
# /Users/mgordon/.virtualenv/production/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in multiply

# %%
np.sign(-100)
# Out:
# -1
